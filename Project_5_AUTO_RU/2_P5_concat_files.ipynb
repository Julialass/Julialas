# %% [markdown]
# # В этом ноутбуке
# - я соединяю  файлы train_p5_full.csv и train_p5_full_SMW.csv с собранными данными по предложениям о продаже машин тех марок, которые есть в тестовом файле, немного ставлю на место информацию, которая попала в неправильное поле из-за того, что предыдущее поле не содержало информации
# - и сохраняю данные в файл parsed_data.csv для дальнейшей обработки

# %%
import json
import pandas as pd
pd.set_option("expand_frame_repr", True)
import numpy as np

# %%
def save_data(title, data):
    with open(title, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)


def load_data(title):
    with open(title, encoding="utf-8") as f:
        return json.load(f)
    
def get_unique_values(non_un_list):
    return list(set(non_un_list))

# %%
train_1=pd.read_csv('train_p5_full.csv')
display(train_1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53163 entries, 0 to 53162
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        53163 non-null  object
#  1   0more        53151 non-null  float64
#  2   1more        53151 non-null  object
#  3   2more        53149 non-null  object
#  4   3more        52998 non-null  object
#  5   model        39124 non-null  object
#  6   год выпуска  53151 non-null  float64
#  7   Пробег       53151 non-null  object
#  8   Кузов        53149 non-null  object
#  9   Цвет         53151 non-null  object
#  10  Двигатель    53149 non-null  object
#  11  Налог        51662 non-null  object
#  12  Коробка      53149 non-null  object
#  13  Привод       53149 non-null  object
#  14  Руль         53151 non-null  object
#  15  Состояние    53151 non-null  object
#  16  Владельцы    53151 non-null  object
#  17  ПТС          53151 non-null  object
# ...

# %%
col1=set(train_1.columns)

# %%
train_2=pd.read_csv('train_p5_full_SMW.csv')
display(train_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17816 entries, 0 to 17815
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        17816 non-null  object
#  1   0more        17812 non-null  float64
#  2   1more        17812 non-null  object
#  3   2more        17812 non-null  object
#  4   3more        17791 non-null  object
#  5   model        17188 non-null  object
#  6   год выпуска  17812 non-null  float64
#  7   Пробег       17812 non-null  object
#  8   Кузов        17812 non-null  object
#  9   Цвет         17812 non-null  object
#  10  Двигатель    17812 non-null  object
#  11  Налог        17125 non-null  object
#  12  Коробка      17812 non-null  object
#  13  Привод       17812 non-null  object
#  14  Руль         17812 non-null  object
#  15  Состояние    17812 non-null  object
#  16  Владельцы    17812 non-null  object
#  17  ПТС          17812 non-null  object
# ...

# %%
col2=set(train_2.columns)

# %%
col1.difference(col2)
# Out:
# set()

# %%
train_2.columns=train_1.columns

# %%
display(train_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17816 entries, 0 to 17815
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        17816 non-null  object
#  1   0more        17812 non-null  float64
#  2   1more        17812 non-null  object
#  3   2more        17812 non-null  object
#  4   3more        17791 non-null  object
#  5   model        17188 non-null  object
#  6   год выпуска  17812 non-null  float64
#  7   Пробег       17812 non-null  object
#  8   Кузов        17812 non-null  object
#  9   Цвет         17812 non-null  object
#  10  Двигатель    17812 non-null  object
#  11  Налог        17125 non-null  object
#  12  Коробка      17812 non-null  object
#  13  Привод       17812 non-null  object
#  14  Руль         17812 non-null  object
#  15  Состояние    17812 non-null  object
#  16  Владельцы    17812 non-null  object
#  17  ПТС          17812 non-null  object
# ...

# %%
train_df=pd.concat([train_1,train_2], axis=0).reset_index()

# %%
display(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70979 entries, 0 to 70978
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        70979 non-null  int64
#  1   brand        70979 non-null  object
#  2   0more        70963 non-null  float64
#  3   1more        70963 non-null  object
#  4   2more        70961 non-null  object
#  5   3more        70789 non-null  object
#  6   model        56312 non-null  object
#  7   год выпуска  70963 non-null  float64
#  8   Пробег       70963 non-null  object
#  9   Кузов        70961 non-null  object
#  10  Цвет         70963 non-null  object
#  11  Двигатель    70961 non-null  object
#  12  Налог        68787 non-null  object
#  13  Коробка      70961 non-null  object
#  14  Привод       70961 non-null  object
#  15  Руль         70963 non-null  object
#  16  Состояние    70963 non-null  object
#  17  Владельцы    70963 non-null  object
# ...

# %%
train_df['price'].value_counts(dropna=False)
# Out:
# NaN               15831
# SOLD               1252
# До апреля 2023      411
# 950000              370
# 750000              333
#                   ...
# 2013265               1
# 249990                1
# 14748000              1
# 4755000               1
# 3659500               1
# Name: price, Length: 5198, dtype: int64

# %%
train_df['model'].value_counts(dropna=False)
# Out:
# NaN                                     14667
# Volkswagen Polo V Рестайлинг              692
# Skoda Octavia III (A7)                    550
# Skoda Octavia II (A5) Рестайлинг          521
# Volkswagen Tiguan I Рестайлинг            502
#                                         ...
# Toyota Wish I Рестайлинг                    1
# Lexus LC  I 500                             1
# Mercedes-Benz GL-Класс  I (X164) 420        1
# Nissan Bluebird X (U13)                     1
# Mitsubishi Emeraude 1992-1996               1
# Name: model, Length: 2638, dtype: int64

# %%
train_df.dropna(subset=['price'],inplace=True)
train_df.dropna(subset=['model'],inplace=True)

# %%
display(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41030 entries, 0 to 70978
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        41030 non-null  int64
#  1   brand        41030 non-null  object
#  2   0more        41030 non-null  float64
#  3   1more        41030 non-null  object
#  4   2more        41028 non-null  object
#  5   3more        40876 non-null  object
#  6   model        41030 non-null  object
#  7   год выпуска  41030 non-null  float64
#  8   Пробег       41030 non-null  object
#  9   Кузов        41028 non-null  object
#  10  Цвет         41030 non-null  object
#  11  Двигатель    41028 non-null  object
#  12  Налог        40044 non-null  object
#  13  Коробка      41028 non-null  object
#  14  Привод       41028 non-null  object
#  15  Руль         41030 non-null  object
#  16  Состояние    41030 non-null  object
#  17  Владельцы    41030 non-null  object
# ...

# %%
train_df['model'].value_counts(dropna=False)
# Out:
# Volkswagen Polo V Рестайлинг                692
# Volkswagen Tiguan I Рестайлинг              502
# Volkswagen Tiguan II                        474
# Toyota Camry VIII (XV70)                    444
# Honda Civic VIII                            440
#                                            ...
# Volkswagen Karmann-Ghia I (Type 14)           1
# Mercedes-Benz CLS AMG  III (C257) 53 AMG      1
# Nissan Altima V (L33) Рестайлинг              1
# Toyota Cami                                   1
# Toyota Mega Cruiser                           1
# Name: model, Length: 2410, dtype: int64

# %%
train_df['price'].value_counts(dropna=False)
# Out:
# SOLD              760
# До апреля 2023    407
# 950000            294
# До марта 2023     265
# 750000            214
#                  ...
# 7530000             1
# 4329000             1
# 4362500             1
# 1653600             1
# 4191899             1
# Name: price, Length: 4649, dtype: int64

# %%
sorted(get_unique_values(train_df['price']), reverse=True)
# Out:
# ['До января 2025',
#  'До января 2024',
#  'До января 2023',
#  'До января 2022',
#  'До февраля 2024',
#  'До февраля 2023',
#  'До февраля 2022',
#  'До февраля 2021',
#  'До сентября 2029',
#  'До сентября 2024',
#  'До сентября 2023',
#  'До сентября 2022',
#  'До сентября 2021',
#  'До сентября 2019',
#  'До октября 2025',
#  'До октября 2024',
#  'До октября 2023',
#  'До октября 2022',
#  'До октября 2021',
#  'До октября 2020',
#  'До ноября 2026',
#  'До ноября 2025',
#  'До ноября 2024',
#  'До ноября 2023',
#  'До ноября 2022',
#  'До ноября 2021',
#  'До ноября 2020',
#  'До мая 2025',
#  'До мая 2024',
#  'До мая 2023',
#  'До мая 2022',
#  'До мая 2021',
#  'До марта 2025',
#  'До марта 2024',
#  'До марта 2023',
#  'До марта 2022',
#  'До марта 2021',
#  'До июня 2030',
#  'До июня 2029',
#  'До июня 2025',
#  'До июня 2023',
#  'До июня 2022',
#  'До июня 2021',
#  'До июля 2025',
#  'До июля 2024',
#  'До июля 2023',
#  'До июля 2022',
#  'До июля 2021',
# ...

# %%
exclude=['До января 2025',
 'До января 2024',
 'До января 2023',
 'До января 2022',
 'До февраля 2024',
 'До февраля 2023',
 'До февраля 2022',
 'До февраля 2021',
 'До сентября 2029',
 'До сентября 2024',
 'До сентября 2023',
 'До сентября 2022',
 'До сентября 2021',
 'До сентября 2019',
 'До октября 2025',
 'До октября 2024',
 'До октября 2023',
 'До октября 2022',
 'До октября 2021',
 'До октября 2020',
 'До ноября 2026',
 'До ноября 2025',
 'До ноября 2024',
 'До ноября 2023',
 'До ноября 2022',
 'До ноября 2021',
 'До ноября 2020',
 'До мая 2025',
 'До мая 2024',
 'До мая 2023',
 'До мая 2022',
 'До мая 2021',
 'До марта 2025',
 'До марта 2024',
 'До марта 2023',
 'До марта 2022',
 'До марта 2021',
 'До июня 2030',
 'До июня 2029',
 'До июня 2025',
 'До июня 2023',
 'До июня 2022',
 'До июня 2021',
 'До июля 2025',
 'До июля 2024',
 'До июля 2023',
 'До июля 2022',
 'До июля 2021',
 'До декабря 2025',
 'До декабря 2024',
 'До декабря 2023',
 'До декабря 2022',
 'До декабря 2021',
 'До апреля 2030',
 'До апреля 2024',
 'До апреля 2023',
 'До апреля 2022',
 'До апреля 2021',
 'До августа 2024',
 'До августа 2023',
 'До августа 2022',
 'До августа 2021',
 'До августа 2020']

# %%
for message in exclude:  # Проверяю, не произошло ли смещения данных из-за разного формата страниц в интернете

    display(train_df[train_df['price']== message])
# Out:
#        index       brand   0more              1more    2more   3more  \
# 53922    759       SKODA  2020.0            лифтбек    белый  Бензин
# 53923    760       SKODA  2020.0            лифтбек    белый  Бензин
# 61090   7927  MITSUBISHI  2020.0  внедорожник 5 дв.    белый  Бензин
# 65993  12830         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 66117  12954         BMW  2020.0  внедорожник 5 дв.   чёрный  Дизель
# 69685  16522         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69723  16560         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69762  16599         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69799  16636         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69837  16674         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69875  16712         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69914  16751         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# 69951  16788         BMW  2019.0  внедорожник 5 дв.  бежевый  Дизель
# ...

# %%
train_df['price']=train_df.apply(lambda row: row['Обмен'] if row['price'] in exclude else row['price'], axis = 1)
sorted(get_unique_values(train_df['price']), reverse=True)
# Out:
# ['SOLD',
#  '999999',
#  '999998',
#  '999990',
#  '99999',
#  '9999000',
#  '999900',
#  '999000',
#  '998000',
#  '997600',
#  '997500',
#  '9970000',
#  '997000',
#  '996000',
#  '995500',
#  '995100',
#  '9950000',
#  '995000',
#  '994000',
#  '993740',
#  '993000',
#  '9900000',
#  '990000',
#  '99000',
#  '9898020',
#  '989000',
#  '988000',
#  '987600',
#  '987000',
#  '986860',
#  '985775',
#  '985700',
#  '985000',
#  '984000',
#  '983350',
#  '982800',
#  '982320',
#  '982000',
#  '980300',
#  '9800000',
#  '980000',
#  '98000',
#  '979900',
#  '979599',
#  '979579',
#  '979000',
#  '9787282',
#  '978000',
#  '977000',
#  '976790',
#  '975000',
#  '974900',
#  '974000',
#  '973000',
#  '971000',
#  '970000',
#  '97000',
#  '969990',
#  '969220',
#  '969000',
#  '968000',
#  '967877',
#  '967000',
#  '966000',
#  '965000',
#  '964000',
#  '963785',
#  '963711',
#  '962000',
#  '960000',
#  '96000',
#  '959420',
#  '959000',
#  '958000',
#  '957000',
#  '955500',
# ...

# %%
train_df['price'].value_counts(dropna=False)
# Out:
# SOLD       760
# 950000     297
# 1299000    247
# 850000     239
# 750000     214
#           ...
# 1979860      1
# 3693000      1
# 495500       1
# 1893000      1
# 4191899      1
# Name: price, Length: 4667, dtype: int64

# %%
train_df=train_df[train_df['price']!=0]

# %%
train_df['price'].value_counts(dropna=False)
# Out:
# SOLD       760
# 950000     297
# 1299000    247
# 850000     239
# 750000     214
#           ...
# 1979860      1
# 3693000      1
# 495500       1
# 1893000      1
# 4191899      1
# Name: price, Length: 4667, dtype: int64

# %%
display(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41030 entries, 0 to 70978
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        41030 non-null  int64
#  1   brand        41030 non-null  object
#  2   0more        41030 non-null  float64
#  3   1more        41030 non-null  object
#  4   2more        41028 non-null  object
#  5   3more        40876 non-null  object
#  6   model        41030 non-null  object
#  7   год выпуска  41030 non-null  float64
#  8   Пробег       41030 non-null  object
#  9   Кузов        41028 non-null  object
#  10  Цвет         41030 non-null  object
#  11  Двигатель    41028 non-null  object
#  12  Налог        40044 non-null  object
#  13  Коробка      41028 non-null  object
#  14  Привод       41028 non-null  object
#  15  Руль         41030 non-null  object
#  16  Состояние    41030 non-null  object
#  17  Владельцы    41030 non-null  object
# ...

# %%
train_df.to_csv('parsed_data.csv',index=False)  # Save the dataframe
